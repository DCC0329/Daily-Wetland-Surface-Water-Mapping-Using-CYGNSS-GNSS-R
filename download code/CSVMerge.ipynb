# %%
import re
from pathlib import Path
import pandas as pd

# ========= CONFIG (edit if needed) =========
IN_DIR = Path("/mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/2019_08")
OUT_CSV = "/mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_08.csv"
# ===========================================

def parse_from_filename(name: str):
    """
    Extract YYYYMMDD from filename and return:
      date_iso (YYYY-MM-DD), julian_day (1..366), julian_date (astronomical JD, float)
    """
    m = re.search(r"(\d{8})", name)
    if not m:
        return None, None, None
    ymd = m.group(1)
    ts = pd.to_datetime(ymd, format="%Y%m%d", errors="coerce")
    if pd.isna(ts):
        return None, None, None
    return ts.date().isoformat(), int(ts.dayofyear), float(pd.Timestamp(ts).to_julian_date())

# Gather daily CSVs only (YYYYMMDD.csv); ignore merge_summary.csv and others
all_csvs = sorted(IN_DIR.glob("*.csv"))
daily_csvs = [p for p in all_csvs if re.fullmatch(r"\d{8}\.csv", p.name)]

if not daily_csvs:
    raise SystemExit(f"[ABORT] No daily CSVs found in: {IN_DIR}")

frames = []
for p in daily_csvs:
    try:
        df = pd.read_csv(p, low_memory=False)
    except Exception as e:
        print(f"[SKIP] Failed to read {p.name}: {e}")
        continue

    date_iso, jday, jdate = parse_from_filename(p.name)
    if date_iso is None:
        print(f"[WARN] Could not parse date from filename: {p.name}")
        continue

    # Add time columns at the front for convenience
    df.insert(0, "date", date_iso)
    df.insert(1, "julian_day", jday)
    df.insert(2, "julian_date", jdate)

    frames.append(df)
    print(f"[OK] {p.name} → date={date_iso}, julian_day={jday}, rows={len(df)}")

# Concatenate
merged = pd.concat(frames, ignore_index=True, sort=False)

# Sort by common keys if present
sort_cols = [c for c in ["date", "sample", "ddm"] if c in merged.columns]
if sort_cols:
    merged = merged.sort_values(sort_cols, kind="mergesort").reset_index(drop=True)

# Write output
merged.to_csv(OUT_CSV, index=False)
print(f"\n✅ Merged {len(daily_csvs)} files → {OUT_CSV}")
print(f"Total rows: {len(merged):,} | Columns: {len(merged.columns)}")
print("First 6 columns:", merged.columns[:6].tolist())
# Out:
# [OK] 20190801.csv → date=2019-08-01, julian_day=213, rows=1990
# [OK] 20190802.csv → date=2019-08-02, julian_day=214, rows=2173
# [OK] 20190803.csv → date=2019-08-03, julian_day=215, rows=2469
# [OK] 20190804.csv → date=2019-08-04, julian_day=216, rows=2229
# [OK] 20190805.csv → date=2019-08-05, julian_day=217, rows=2403
# [OK] 20190806.csv → date=2019-08-06, julian_day=218, rows=2050
# [OK] 20190807.csv → date=2019-08-07, julian_day=219, rows=2329
# [OK] 20190808.csv → date=2019-08-08, julian_day=220, rows=2531
# [OK] 20190809.csv → date=2019-08-09, julian_day=221, rows=2352
# [OK] 20190810.csv → date=2019-08-10, julian_day=222, rows=2589
# [OK] 20190811.csv → date=2019-08-11, julian_day=223, rows=2030
# [OK] 20190812.csv → date=2019-08-12, julian_day=224, rows=2361
# [OK] 20190813.csv → date=2019-08-13, julian_day=225, rows=2347
# [OK] 20190814.csv → date=2019-08-14, julian_day=226, rows=2206
# [OK] 20190815.csv → date=2019-08-15, julian_day=227, rows=2506
# [OK] 20190816.csv → date=2019-08-16, julian_day=228, rows=2209
# [OK] 20190817.csv → date=2019-08-17, julian_day=229, rows=2395
# [OK] 20190818.csv → date=2019-08-18, julian_day=230, rows=2171
# [OK] 20190819.csv → date=2019-08-19, julian_day=231, rows=2290
# [OK] 20190820.csv → date=2019-08-20, julian_day=232, rows=2495
# [OK] 20190821.csv → date=2019-08-21, julian_day=233, rows=2402
# [OK] 20190822.csv → date=2019-08-22, julian_day=234, rows=2814
# [OK] 20190823.csv → date=2019-08-23, julian_day=235, rows=2029
# [OK] 20190824.csv → date=2019-08-24, julian_day=236, rows=2288
# [OK] 20190825.csv → date=2019-08-25, julian_day=237, rows=2284
# [OK] 20190826.csv → date=2019-08-26, julian_day=238, rows=2371
# [OK] 20190827.csv → date=2019-08-27, julian_day=239, rows=2524
# [OK] 20190828.csv → date=2019-08-28, julian_day=240, rows=2136
# [OK] 20190829.csv → date=2019-08-29, julian_day=241, rows=2437
# [OK] 20190830.csv → date=2019-08-30, julian_day=242, rows=2039
# [OK] 20190831.csv → date=2019-08-31, julian_day=243, rows=1851
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_08.csv
# Total rows: 71,300 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']

# %%
# -*- coding: utf-8 -*-
import re
from pathlib import Path
import pandas as pd

# ========= CONFIG =========
ROOT_DIR = Path("/mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/")
OUT_DIR  = ROOT_DIR / "monthly"
OUT_DIR.mkdir(exist_ok=True)
# ===========================

def parse_from_filename(name: str):
    """
    Extract YYYYMMDD from filename and return:
      date_iso (YYYY-MM-DD), julian_day (1..366), julian_date (astronomical JD, float)
    """
    m = re.search(r"(\d{8})", name)
    if not m:
        return None, None, None
    ymd = m.group(1)
    ts = pd.to_datetime(ymd, format="%Y%m%d", errors="coerce")
    if pd.isna(ts):
        return None, None, None
    return ts.date().isoformat(), int(ts.dayofyear), float(pd.Timestamp(ts).to_julian_date())

# ============ LOOP ============
for year in range(2018, 2026):         # 2018 → 2025 inclusive
    for month in range(1, 13):
        ym = f"{year}_{month:02d}"
        in_dir = ROOT_DIR / ym
        if not in_dir.exists():
            print(f"[SKIP] {ym}: folder does not exist")
            continue

        # Gather daily CSVs
        all_csvs   = sorted(in_dir.glob("*.csv"))
        daily_csvs = [p for p in all_csvs if re.fullmatch(r"\d{8}\.csv", p.name)]

        if not daily_csvs:
            print(f"[SKIP] {ym}: no daily CSVs")
            continue

        frames = []
        for p in daily_csvs:
            try:
                df = pd.read_csv(p, low_memory=False)
            except Exception as e:
                print(f"[SKIP] Failed to read {p.name}: {e}")
                continue

            date_iso, jday, jdate = parse_from_filename(p.name)
            if date_iso is None:
                print(f"[WARN] Could not parse date from filename: {p.name}")
                continue

            # Add time columns
            df.insert(0, "date", date_iso)
            df.insert(1, "julian_day", jday)
            df.insert(2, "julian_date", jdate)

            frames.append(df)
            print(f"[OK] {ym}/{p.name} → date={date_iso}, rows={len(df)}")

        if not frames:
            print(f"[WARN] {ym}: no valid data loaded")
            continue

        merged = pd.concat(frames, ignore_index=True, sort=False)

        # Sort if possible
        sort_cols = [c for c in ["date", "sample", "ddm"] if c in merged.columns]
        if sort_cols:
            merged = merged.sort_values(sort_cols, kind="mergesort").reset_index(drop=True)

        out_csv = OUT_DIR / f"{ym}.csv"
        merged.to_csv(out_csv, index=False)

        print(f"\n✅ Merged {len(daily_csvs)} files → {out_csv}")
        print(f"Total rows: {len(merged):,} | Columns: {len(merged.columns)}")
        print("First 6 columns:", merged.columns[:6].tolist(), "\n")
# Out:
# [SKIP] 2018_01: folder does not exist
# [SKIP] 2018_02: folder does not exist
# [SKIP] 2018_03: folder does not exist
# [SKIP] 2018_04: folder does not exist
# [SKIP] 2018_05: folder does not exist
# [SKIP] 2018_06: folder does not exist
# [SKIP] 2018_07: folder does not exist
# [OK] 2018_08/20180801.csv → date=2018-08-01, rows=930
# [OK] 2018_08/20180802.csv → date=2018-08-02, rows=892
# [OK] 2018_08/20180803.csv → date=2018-08-03, rows=894
# [OK] 2018_08/20180804.csv → date=2018-08-04, rows=760
# [OK] 2018_08/20180805.csv → date=2018-08-05, rows=808
# [OK] 2018_08/20180806.csv → date=2018-08-06, rows=813
# [OK] 2018_08/20180807.csv → date=2018-08-07, rows=788
# [OK] 2018_08/20180808.csv → date=2018-08-08, rows=915
# [OK] 2018_08/20180809.csv → date=2018-08-09, rows=890
# [OK] 2018_08/20180810.csv → date=2018-08-10, rows=859
# [OK] 2018_08/20180811.csv → date=2018-08-11, rows=927
# [OK] 2018_08/20180812.csv → date=2018-08-12, rows=864
# [OK] 2018_08/20180813.csv → date=2018-08-13, rows=832
# [OK] 2018_08/20180814.csv → date=2018-08-14, rows=1120
# [OK] 2018_08/20180815.csv → date=2018-08-15, rows=1094
# [OK] 2018_08/20180816.csv → date=2018-08-16, rows=1140
# [OK] 2018_08/20180817.csv → date=2018-08-17, rows=1161
# [OK] 2018_08/20180818.csv → date=2018-08-18, rows=1092
# [OK] 2018_08/20180819.csv → date=2018-08-19, rows=1114
# [OK] 2018_08/20180820.csv → date=2018-08-20, rows=1170
# [OK] 2018_08/20180821.csv → date=2018-08-21, rows=1158
# [OK] 2018_08/20180822.csv → date=2018-08-22, rows=1077
# [OK] 2018_08/20180823.csv → date=2018-08-23, rows=1078
# [OK] 2018_08/20180824.csv → date=2018-08-24, rows=1087
# [OK] 2018_08/20180825.csv → date=2018-08-25, rows=1113
# [OK] 2018_08/20180826.csv → date=2018-08-26, rows=1169
# [OK] 2018_08/20180827.csv → date=2018-08-27, rows=880
# [OK] 2018_08/20180828.csv → date=2018-08-28, rows=746
# [OK] 2018_08/20180829.csv → date=2018-08-29, rows=710
# [OK] 2018_08/20180830.csv → date=2018-08-30, rows=878
# [OK] 2018_08/20180831.csv → date=2018-08-31, rows=810
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2018_08.csv
# Total rows: 29,769 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 
| Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2018_12/20181201.csv → date=2018-12-01, rows=1254
# [OK] 2018_12/20181202.csv → date=2018-12-02, rows=1136
# [OK] 2018_12/20181203.csv → date=2018-12-03, rows=1143
# [OK] 2018_12/20181204.csv → date=2018-12-04, rows=1184
# [OK] 2018_12/20181205.csv → date=2018-12-05, rows=1022
# [OK] 2018_12/20181206.csv → date=2018-12-06, rows=1006
# [OK] 2018_12/20181207.csv → date=2018-12-07, rows=1154
# [OK] 2018_12/20181208.csv → date=2018-12-08, rows=1084
# [OK] 2018_12/20181209.csv → date=2018-12-09, rows=990
# [OK] 2018_12/20181210.csv → date=2018-12-10, rows=837
# [OK] 2018_12/20181211.csv → date=2018-12-11, rows=1287
# [OK] 2018_12/20181212.csv → date=2018-12-12, rows=1128
# [OK] 2018_12/20181213.csv → date=2018-12-13, rows=1250
# [OK] 2018_12/20181214.csv → date=2018-12-14, rows=1126
# [OK] 2018_12/20181215.csv → date=2018-12-15, rows=1085
# [OK] 2018_12/20181216.csv → date=2018-12-16, rows=1217
# [OK] 2018_12/20181217.csv → date=2018-12-17, rows=1158
# [OK] 2018_12/20181218.csv → date=2018-12-18, rows=1205
# [OK] 2018_12/20181219.csv → date=2018-12-19, rows=1093
# [OK] 2018_12/20181220.csv → date=2018-12-20, rows=1172
# [OK] 2018_12/20181221.csv → date=2018-12-21, rows=1116
# [OK] 2018_12/20181222.csv → date=2018-12-22, rows=1053
# [OK] 2018_12/20181223.csv → date=2018-12-23, rows=1380
# [OK] 2018_12/20181224.csv → date=2018-12-24, rows=1135
# [OK] 2018_12/20181225.csv → date=2018-12-25, rows=1432
# [OK] 2018_12/20181226.csv → date=2018-12-26, rows=1085
# [OK] 2018_12/20181227.csv → date=2018-12-27, rows=1066
# [OK] 2018_12/20181228.csv → date=2018-12-28, rows=1126
# [OK] 2018_12/20181229.csv → date=2018-12-29, rows=1094
# [OK] 2018_12/20181230.csv → date=2018-12-30, rows=1202
# [OK] 2018_12/20181231.csv → date=2018-12-31, rows=1173
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2018_12.csv
# Total rows: 35,393 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_01/20190101.csv → date=2019-01-01, rows=1201
# [OK] 2019_01/20190102.csv → date=2019-01-02, rows=1066
# [OK] 2019_01/20190103.csv → date=2019-01-03, rows=943
# [OK] 2019_01/20190104.csv → date=2019-01-04, rows=1201
# [OK] 2019_01/20190105.csv → date=2019-01-05, rows=1074
# [OK] 2019_01/20190106.csv → date=2019-01-06, rows=1252
# [OK] 2019_01/20190107.csv → date=2019-01-07, rows=1160
# [OK] 2019_01/20190108.csv → date=2019-01-08, rows=1230
# [OK] 2019_01/20190109.csv → date=2019-01-09, rows=1103
# [OK] 2019_01/20190110.csv → date=2019-01-10, rows=1059
# [OK] 2019_01/20190111.csv → date=2019-01-11, rows=1163
# [OK] 2019_01/20190112.csv → date=2019-01-12, rows=1107
# [OK] 2019_01/20190113.csv → date=2019-01-13, rows=995
# [OK] 2019_01/20190114.csv → date=2019-01-14, rows=1034
# [OK] 2019_01/20190115.csv → date=2019-01-15, rows=918
# [OK] 2019_01/20190116.csv → date=2019-01-16, rows=1194
# [OK] 2019_01/20190117.csv → date=2019-01-17, rows=1077
# [OK] 2019_01/20190118.csv → date=2019-01-18, rows=1307
# [OK] 2019_01/20190119.csv → date=2019-01-19, rows=966
# [OK] 2019_01/20190120.csv → date=2019-01-20, rows=1117
# [OK] 2019_01/20190121.csv → date=2019-01-21, rows=1023
# [OK] 2019_01/20190122.csv → date=2019-01-22, rows=1056
# [OK] 2019_01/20190123.csv → date=2019-01-23, rows=1226
# [OK] 2019_01/20190124.csv → date=2019-01-24, rows=1112
# [OK] 2019_01/20190125.csv → date=2019-01-25, rows=1133
# [OK] 2019_01/20190126.csv → date=2019-01-26, rows=1078
# [OK] 2019_01/20190127.csv → date=2019-01-27, rows=1126
# [OK] 2019_01/20190128.csv → date=2019-01-28, rows=1278
# [OK] 2019_01/20190129.csv → date=2019-01-29, rows=1029
# [OK] 2019_01/20190130.csv → date=2019-01-30, rows=1189
# [OK] 2019_01/20190131.csv → date=2019-01-31, rows=1034
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_01.csv
# Total rows: 34,451 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_02/20190201.csv → date=2019-02-01, rows=1115
# [OK] 2019_02/20190202.csv → date=2019-02-02, rows=1136
# [OK] 2019_02/20190203.csv → date=2019-02-03, rows=1023
# [OK] 2019_02/20190204.csv → date=2019-02-04, rows=1189
# [OK] 2019_02/20190205.csv → date=2019-02-05, rows=1129
# [OK] 2019_02/20190206.csv → date=2019-02-06, rows=1141
# [OK] 2019_02/20190207.csv → date=2019-02-07, rows=896
# [OK] 2019_02/20190208.csv → date=2019-02-08, rows=1023
# [OK] 2019_02/20190209.csv → date=2019-02-09, rows=1327
# [OK] 2019_02/20190210.csv → date=2019-02-10, rows=1077
# [OK] 2019_02/20190211.csv → date=2019-02-11, rows=1200
# [OK] 2019_02/20190212.csv → date=2019-02-12, rows=1087
# [OK] 2019_02/20190213.csv → date=2019-02-13, rows=944
# [OK] 2019_02/20190214.csv → date=2019-02-14, rows=995
# [OK] 2019_02/20190215.csv → date=2019-02-15, rows=674
# [OK] 2019_02/20190216.csv → date=2019-02-16, rows=1368
# [OK] 2019_02/20190217.csv → date=2019-02-17, rows=1027
# [OK] 2019_02/20190218.csv → date=2019-02-18, rows=1043
# [OK] 2019_02/20190219.csv → date=2019-02-19, rows=1129
# [OK] 2019_02/20190220.csv → date=2019-02-20, rows=987
# [OK] 2019_02/20190221.csv → date=2019-02-21, rows=1233
# [OK] 2019_02/20190222.csv → date=2019-02-22, rows=1103
# [OK] 2019_02/20190223.csv → date=2019-02-23, rows=1290
# [OK] 2019_02/20190224.csv → date=2019-02-24, rows=1035
# [OK] 2019_02/20190225.csv → date=2019-02-25, rows=1193
# [OK] 2019_02/20190226.csv → date=2019-02-26, rows=1128
# [OK] 2019_02/20190227.csv → date=2019-02-27, rows=1053
# [OK] 2019_02/20190228.csv → date=2019-02-28, rows=1055
#
# ✅ Merged 28 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_02.csv
# Total rows: 30,600 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019
| Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_06/20190601.csv → date=2019-06-01, rows=1171
# [OK] 2019_06/20190602.csv → date=2019-06-02, rows=1138
# [OK] 2019_06/20190603.csv → date=2019-06-03, rows=1111
# [OK] 2019_06/20190604.csv → date=2019-06-04, rows=1216
# [OK] 2019_06/20190605.csv → date=2019-06-05, rows=1019
# [OK] 2019_06/20190606.csv → date=2019-06-06, rows=1176
# [OK] 2019_06/20190607.csv → date=2019-06-07, rows=1036
# [OK] 2019_06/20190608.csv → date=2019-06-08, rows=1202
# [OK] 2019_06/20190609.csv → date=2019-06-09, rows=1247
# [OK] 2019_06/20190610.csv → date=2019-06-10, rows=1148
# [OK] 2019_06/20190611.csv → date=2019-06-11, rows=1179
# [OK] 2019_06/20190612.csv → date=2019-06-12, rows=1054
# [OK] 2019_06/20190613.csv → date=2019-06-13, rows=1149
# [OK] 2019_06/20190614.csv → date=2019-06-14, rows=1169
# [OK] 2019_06/20190615.csv → date=2019-06-15, rows=1005
# [OK] 2019_06/20190616.csv → date=2019-06-16, rows=1214
# [OK] 2019_06/20190617.csv → date=2019-06-17, rows=1137
# [OK] 2019_06/20190618.csv → date=2019-06-18, rows=1175
# [OK] 2019_06/20190619.csv → date=2019-06-19, rows=1113
# [OK] 2019_06/20190620.csv → date=2019-06-20, rows=1081
# [OK] 2019_06/20190621.csv → date=2019-06-21, rows=1169
# [OK] 2019_06/20190622.csv → date=2019-06-22, rows=1248
# [OK] 2019_06/20190623.csv → date=2019-06-23, rows=1371
# [OK] 2019_06/20190624.csv → date=2019-06-24, rows=1170
# [OK] 2019_06/20190625.csv → date=2019-06-25, rows=1340
# [OK] 2019_06/20190626.csv → date=2019-06-26, rows=1281
# [OK] 2019_06/20190627.csv → date=2019-06-27, rows=1201
# [OK] 2019_06/20190628.csv → date=2019-06-28, rows=1373
# [OK] 2019_06/20190629.csv → date=2019-06-29, rows=1060
# [OK] 2019_06/20190630.csv → date=2019-06-30, rows=1307
#
# ✅ Merged 30 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_06.csv
# Total rows: 35,260 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_07/20190701.csv → date=2019-07-01, rows=1230
# [OK] 2019_07/20190702.csv → date=2019-07-02, rows=1505
# [OK] 2019_07/20190703.csv → date=2019-07-03, rows=2470
# [OK] 2019_07/20190704.csv → date=2019-07-04, rows=2240
# [OK] 2019_07/20190705.csv → date=2019-07-05, rows=2435
# [OK] 2019_07/20190706.csv → date=2019-07-06, rows=1842
# [OK] 2019_07/20190707.csv → date=2019-07-07, rows=2128
# [OK] 2019_07/20190708.csv → date=2019-07-08, rows=2384
# [OK] 2019_07/20190709.csv → date=2019-07-09, rows=2061
# [OK] 2019_07/20190710.csv → date=2019-07-10, rows=2327
# [OK] 2019_07/20190711.csv → date=2019-07-11, rows=2208
# [OK] 2019_07/20190712.csv → date=2019-07-12, rows=2126
# [OK] 2019_07/20190713.csv → date=2019-07-13, rows=2048
# [OK] 2019_07/20190714.csv → date=2019-07-14, rows=2327
# [OK] 2019_07/20190715.csv → date=2019-07-15, rows=2498
# [OK] 2019_07/20190716.csv → date=2019-07-16, rows=2379
# [OK] 2019_07/20190717.csv → date=2019-07-17, rows=2481
# [OK] 2019_07/20190718.csv → date=2019-07-18, rows=1978
# [OK] 2019_07/20190719.csv → date=2019-07-19, rows=2234
# [OK] 2019_07/20190720.csv → date=2019-07-20, rows=2336
# [OK] 2019_07/20190721.csv → date=2019-07-21, rows=2205
# [OK] 2019_07/20190722.csv → date=2019-07-22, rows=2657
# [OK] 2019_07/20190723.csv → date=2019-07-23, rows=2306
# [OK] 2019_07/20190724.csv → date=2019-07-24, rows=2299
# [OK] 2019_07/20190725.csv → date=2019-07-25, rows=2171
# [OK] 2019_07/20190726.csv → date=2019-07-26, rows=2429
# [OK] 2019_07/20190727.csv → date=2019-07-27, rows=2569
# [OK] 2019_07/20190728.csv → date=2019-07-28, rows=2349
# [OK] 2019_07/20190729.csv → date=2019-07-29, rows=2482
# [OK] 2019_07/20190730.csv → date=2019-07-30, rows=1932
# [OK] 2019_07/20190731.csv → date=2019-07-31, rows=2101
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_07.csv
# Total rows: 68,737 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_08/20190801.csv → date=2019-08-01, rows=1990
# [OK] 2019_08/20190802.csv → date=2019-08-02, rows=2173
# [OK] 2019_08/20190803.csv → date=2019-08-03, rows=2469
# [OK] 2019_08/20190804.csv → date=2019-08-04, rows=2229
# [OK] 2019_08/20190805.csv → date=2019-08-05, rows=2403
# [OK] 2019_08/20190806.csv → date=2019-08-06, rows=2050
# [OK] 2019_08/20190807.csv → date=2019-08-07, rows=2329
# [OK] 2019_08/20190808.csv → date=2019-08-08, rows=2531
# [OK] 2019_08/20190809.csv → date=2019-08-09, rows=2352
# [OK] 2019_08/20190810.csv → date=2019-08-10, rows=2589
# [OK] 2019_08/20190811.csv → date=2019-08-11, rows=2030
# [OK] 2019_08/20190812.csv → date=2019-08-12, rows=2361
# [OK] 2019_08/20190813.csv → date=2019-08-13, rows=2347
# [OK] 2019_08/20190814.csv → date=2019-08-14, rows=2206
# [OK] 2019_08/20190815.csv → date=2019-08-15, rows=2506
# [OK] 2019_08/20190816.csv → date=2019-08-16, rows=2209
# [OK] 2019_08/20190817.csv → date=2019-08-17, rows=2395
# [OK] 2019_08/20190818.csv → date=2019-08-18, rows=2171
# [OK] 2019_08/20190819.csv → date=2019-08-19, rows=2290
# [OK] 2019_08/20190820.csv → date=2019-08-20, rows=2495
# [OK] 2019_08/20190821.csv → date=2019-08-21, rows=2402
# [OK] 2019_08/20190822.csv → date=2019-08-22, rows=2814
# [OK] 2019_08/20190823.csv → date=2019-08-23, rows=2029
# [OK] 2019_08/20190824.csv → date=2019-08-24, rows=2288
# [OK] 2019_08/20190825.csv → date=2019-08-25, rows=2284
# [OK] 2019_08/20190826.csv → date=2019-08-26, rows=2371
# [OK] 2019_08/20190827.csv → date=2019-08-27, rows=2524
# [OK] 2019_08/20190828.csv → date=2019-08-28, rows=2136
# [OK] 2019_08/20190829.csv → date=2019-08-29, rows=2437
# [OK] 2019_08/20190830.csv → date=2019-08-30, rows=2039
# [OK] 2019_08/20190831.csv → date=2019-08-31, rows=1851
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_08.csv
# Total rows: 71,300 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_09/20190901.csv → date=2019-09-01, rows=2562
# [OK] 2019_09/20190902.csv → date=2019-09-02, rows=2379
# [OK] 2019_09/20190903.csv → date=2019-09-03, rows=2756
# [OK] 2019_09/20190904.csv → date=2019-09-04, rows=2376
# [OK] 2019_09/20190905.csv → date=2019-09-05, rows=2472
# [OK] 2019_09/20190906.csv → date=2019-09-06, rows=2291
# [OK] 2019_09/20190907.csv → date=2019-09-07, rows=2124
# [OK] 2019_09/20190908.csv → date=2019-09-08, rows=2293
# [OK] 2019_09/20190909.csv → date=2019-09-09, rows=1965
# [OK] 2019_09/20190910.csv → date=2019-09-10, rows=2483
# [OK] 2019_09/20190911.csv → date=2019-09-11, rows=2182
# [OK] 2019_09/20190912.csv → date=2019-09-12, rows=2435
# [OK] 2019_09/20190913.csv → date=2019-09-13, rows=2465
# [OK] 2019_09/20190914.csv → date=2019-09-14, rows=1995
# [OK] 2019_09/20190915.csv → date=2019-09-15, rows=2819
# [OK] 2019_09/20190916.csv → date=2019-09-16, rows=2184
# [OK] 2019_09/20190917.csv → date=2019-09-17, rows=2326
# [OK] 2019_09/20190918.csv → date=2019-09-18, rows=2423
# [OK] 2019_09/20190919.csv → date=2019-09-19, rows=1965
# [OK] 2019_09/20190920.csv → date=2019-09-20, rows=2290
# [OK] 2019_09/20190921.csv → date=2019-09-21, rows=2098
# [OK] 2019_09/20190922.csv → date=2019-09-22, rows=2431
# [OK] 2019_09/20190923.csv → date=2019-09-23, rows=2052
# [OK] 2019_09/20190924.csv → date=2019-09-24, rows=2090
# [OK] 2019_09/20190925.csv → date=2019-09-25, rows=2270
# [OK] 2019_09/20190926.csv → date=2019-09-26, rows=2251
# [OK] 2019_09/20190927.csv → date=2019-09-27, rows=2806
# [OK] 2019_09/20190928.csv → date=2019-09-28, rows=2222
# [OK] 2019_09/20190929.csv → date=2019-09-29, rows=2450
# [OK] 2019_09/20190930.csv → date=2019-09-30, rows=2195
#
# ✅ Merged 30 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2019_09.csv
# Total rows: 69,650 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2019_10/20191001.csv → date=2019-10-01, rows=2305
# [OK] 2019_10/20191002.csv → date=2019-10-02, rows=2606
# [OK] 2019_10/20191003.csv → date=2019-10-03, rows=2066
# [OK] 2019_10/20191004.csv → date=2019-10-04, rows=2546
# [OK] 2019_10/20191005.csv → date=2019-10-05, rows=2214
# [OK] 2019_10/20191006.csv → date=2019-10-06, rows=2547
# [OK] 2019_10/20191007.csv → date=2019-10-07, rows=2591
# [OK] 2019_10/20191008.csv → date=2019-10-08, rows=2354
# [OK] 2019_10/20191009.csv → date=2019-10-09, rows=2641
# [OK] 2019_10/20191010.csv → date=2019-10-10, rows=2066
# [OK] 2019_10/20191011.csv → date=2019-10-11, rows=2473
# [OK] 2019_10/20191012.csv → date=2019-10-12, rows=2301
# [OK] 2019_10/20191013.csv → date=2019-10-13, rows=2363
# [OK] 2019_10/20191014.csv → date=2019-10-14, rows=2848
# [OK] 2019_10/20191015.csv → date=2019-10-15, rows=1901
# [OK] 2019_10/20191016.csv → date=2019-10-16, rows=2033
# [OK] 2019_10/20191017.csv → date=2019-10-17, rows=1862
# [OK] 2019_10/20191018.csv → date=2019-10-18, rows=2324
| Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [OK] 2025_07/20250701.csv → date=2025-07-01, rows=1984
# [OK] 2025_07/20250702.csv → date=2025-07-02, rows=2182
# [OK] 2025_07/20250703.csv → date=2025-07-03, rows=2062
# [OK] 2025_07/20250704.csv → date=2025-07-04, rows=1982
# [OK] 2025_07/20250705.csv → date=2025-07-05, rows=2047
# [OK] 2025_07/20250706.csv → date=2025-07-06, rows=2092
# [OK] 2025_07/20250707.csv → date=2025-07-07, rows=2129
# [OK] 2025_07/20250708.csv → date=2025-07-08, rows=2136
# [OK] 2025_07/20250709.csv → date=2025-07-09, rows=2206
# [OK] 2025_07/20250710.csv → date=2025-07-10, rows=1576
# [OK] 2025_07/20250711.csv → date=2025-07-11, rows=2209
# [OK] 2025_07/20250712.csv → date=2025-07-12, rows=2088
# [OK] 2025_07/20250713.csv → date=2025-07-13, rows=2084
# [OK] 2025_07/20250714.csv → date=2025-07-14, rows=2043
# [OK] 2025_07/20250715.csv → date=2025-07-15, rows=1964
# [OK] 2025_07/20250716.csv → date=2025-07-16, rows=2144
# [OK] 2025_07/20250717.csv → date=2025-07-17, rows=2105
# [OK] 2025_07/20250718.csv → date=2025-07-18, rows=2041
# [OK] 2025_07/20250719.csv → date=2025-07-19, rows=2257
# [OK] 2025_07/20250720.csv → date=2025-07-20, rows=2094
# [OK] 2025_07/20250721.csv → date=2025-07-21, rows=2254
# [OK] 2025_07/20250722.csv → date=2025-07-22, rows=1815
# [OK] 2025_07/20250723.csv → date=2025-07-23, rows=1970
# [OK] 2025_07/20250724.csv → date=2025-07-24, rows=1945
# [OK] 2025_07/20250725.csv → date=2025-07-25, rows=2019
# [OK] 2025_07/20250726.csv → date=2025-07-26, rows=1887
# [OK] 2025_07/20250727.csv → date=2025-07-27, rows=1960
# [OK] 2025_07/20250728.csv → date=2025-07-28, rows=2034
# [OK] 2025_07/20250729.csv → date=2025-07-29, rows=1822
# [OK] 2025_07/20250730.csv → date=2025-07-30, rows=2107
# [OK] 2025_07/20250731.csv → date=2025-07-31, rows=2082
#
# ✅ Merged 31 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly/2025_07.csv
# Total rows: 63,320 | Columns: 29
# First 6 columns: ['date', 'julian_day', 'julian_date', 'sample', 'ddm', 'sp_lon']
#
# [SKIP] 2025_08: folder does not exist
# [SKIP] 2025_09: folder does not exist
# [SKIP] 2025_10: folder does not exist
# [SKIP] 2025_11: folder does not exist
# [SKIP] 2025_12: folder does not exist

# %%
import re
from pathlib import Path
import pandas as pd

# ============ CONFIG ============
IN_DIR = Path("/mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/monthly")
OUT_CSV = "/mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/2018to2025_water_fraction.csv"
# =================================

def parse_from_filename(name: str):
    """
    Extract YYYY_MM from filename and return (year_month, datetime).
    """
    m = re.fullmatch(r"(\d{4})_(\d{2})\.csv", name)
    if not m:
        return None, None
    year, month = int(m.group(1)), int(m.group(2))
    ts = pd.Timestamp(year=year, month=month, day=1)
    return f"{year}-{month:02d}", ts

# Gather monthly CSVs
all_csvs = sorted(IN_DIR.glob("*.csv"))
monthly_csvs = [p for p in all_csvs if re.fullmatch(r"\d{4}_\d{2}\.csv", p.name)]

if not monthly_csvs:
    raise SystemExit(f"[ABORT] No monthly CSVs found in: {IN_DIR}")

frames = []
for p in monthly_csvs:
    try:
        df = pd.read_csv(p, low_memory=False)
    except Exception as e:
        print(f"[SKIP] Failed to read {p.name}: {e}")
        continue

    ym_str, ts = parse_from_filename(p.name)
    if ym_str is None:
        print(f"[WARN] Could not parse year_month from filename: {p.name}")
        continue

    # Add metadata columns
    df.insert(0, "year_month", ym_str)
    df.insert(1, "datetime", ts)

    frames.append(df)
    print(f"[OK] {p.name} → year_month={ym_str}, rows={len(df)}")

# Concatenate
merged = pd.concat(frames, ignore_index=True, sort=False)

# Sort by datetime if present
if "datetime" in merged.columns:
    merged = merged.sort_values("datetime", kind="mergesort").reset_index(drop=True)

# Write output
merged.to_csv(OUT_CSV, index=False)
print(f"\n✅ Merged {len(monthly_csvs)} files → {OUT_CSV}")
print(f"Total rows: {len(merged):,} | Columns: {len(merged.columns)}")
print("First 6 columns:", merged.columns[:6].tolist())
# Out:
# [OK] 2018_08.csv → year_month=2018-08, rows=29769
# [OK] 2018_09.csv → year_month=2018-09, rows=30511
# [OK] 2018_10.csv → year_month=2018-10, rows=34702
# [OK] 2018_11.csv → year_month=2018-11, rows=34078
# [OK] 2018_12.csv → year_month=2018-12, rows=35393
# [OK] 2019_01.csv → year_month=2019-01, rows=34451
# [OK] 2019_02.csv → year_month=2019-02, rows=30600
# [OK] 2019_03.csv → year_month=2019-03, rows=35586
# [OK] 2019_04.csv → year_month=2019-04, rows=33954
# [OK] 2019_05.csv → year_month=2019-05, rows=34622
# [OK] 2019_06.csv → year_month=2019-06, rows=35260
# [OK] 2019_07.csv → year_month=2019-07, rows=68737
# [OK] 2019_08.csv → year_month=2019-08, rows=71300
# [OK] 2019_09.csv → year_month=2019-09, rows=69650
# [OK] 2019_10.csv → year_month=2019-10, rows=73445
# [OK] 2019_11.csv → year_month=2019-11, rows=73707
# [OK] 2019_12.csv → year_month=2019-12, rows=75462
# [OK] 2020_01.csv → year_month=2020-01, rows=74468
# [OK] 2020_02.csv → year_month=2020-02, rows=67506
# [OK] 2020_03.csv → year_month=2020-03, rows=73743
# [OK] 2020_04.csv → year_month=2020-04, rows=73826
# [OK] 2020_05.csv → year_month=2020-05, rows=73120
# [OK] 2020_06.csv → year_month=2020-06, rows=70036
# [OK] 2020_07.csv → year_month=2020-07, rows=74388
# [OK] 2020_08.csv → year_month=2020-08, rows=76098
# [OK] 2020_09.csv → year_month=2020-09, rows=73260
# [OK] 2020_10.csv → year_month=2020-10, rows=76025
# [OK] 2020_11.csv → year_month=2020-11, rows=72388
# [OK] 2020_12.csv → year_month=2020-12, rows=71947
# [OK] 2021_01.csv → year_month=2021-01, rows=71012
# [OK] 2021_02.csv → year_month=2021-02, rows=67715
# [OK] 2021_03.csv → year_month=2021-03, rows=74273
# [OK] 2021_04.csv → year_month=2021-04, rows=72717
# [OK] 2021_05.csv → year_month=2021-05, rows=73361
# [OK] 2021_06.csv → year_month=2021-06, rows=69118
# [OK] 2021_07.csv → year_month=2021-07, rows=71332
# [OK] 2021_08.csv → year_month=2021-08, rows=74482
# [OK] 2021_09.csv → year_month=2021-09, rows=73238
# [OK] 2021_10.csv → year_month=2021-10, rows=75620
# [OK] 2021_11.csv → year_month=2021-11, rows=68069
# [OK] 2021_12.csv → year_month=2021-12, rows=66763
# [OK] 2022_01.csv → year_month=2022-01, rows=45912
# [OK] 2022_02.csv → year_month=2022-02, rows=42013
# [OK] 2022_03.csv → year_month=2022-03, rows=47930
# [OK] 2022_04.csv → year_month=2022-04, rows=46184
# [OK] 2022_05.csv → year_month=2022-05, rows=44392
# [OK] 2022_06.csv → year_month=2022-06, rows=45815
# [OK] 2022_07.csv → year_month=2022-07, rows=46158
# [OK] 2022_08.csv → year_month=2022-08, rows=47690
# [OK] 2022_09.csv → year_month=2022-09, rows=48618
# [OK] 2022_10.csv → year_month=2022-10, rows=46655
# [OK] 2022_11.csv → year_month=2022-11, rows=49459
# [OK] 2022_12.csv → year_month=2022-12, rows=43613
# [OK] 2023_01.csv → year_month=2023-01, rows=43820
# [OK] 2023_02.csv → year_month=2023-02, rows=38872
# [OK] 2023_03.csv → year_month=2023-03, rows=43890
# [OK] 2023_04.csv → year_month=2023-04, rows=42585
# [OK] 2023_05.csv → year_month=2023-05, rows=43104
# [OK] 2023_06.csv → year_month=2023-06, rows=38151
# [OK] 2023_07.csv → year_month=2023-07, rows=39711
# [OK] 2023_08.csv → year_month=2023-08, rows=41999
# [OK] 2023_09.csv → year_month=2023-09, rows=42928
# [OK] 2023_10.csv → year_month=2023-10, rows=41113
# [OK] 2023_11.csv → year_month=2023-11, rows=41977
# [OK] 2023_12.csv → year_month=2023-12, rows=43717
# [OK] 2024_01.csv → year_month=2024-01, rows=42082
# [OK] 2024_02.csv → year_month=2024-02, rows=38008
# [OK] 2024_03.csv → year_month=2024-03, rows=42950
# [OK] 2024_04.csv → year_month=2024-04, rows=41832
# [OK] 2024_05.csv → year_month=2024-05, rows=40351
# [OK] 2024_06.csv → year_month=2024-06, rows=37477
# [OK] 2024_07.csv → year_month=2024-07, rows=39498
# [OK] 2024_08.csv → year_month=2024-08, rows=42336
# [OK] 2024_09.csv → year_month=2024-09, rows=41291
# [OK] 2024_10.csv → year_month=2024-10, rows=43321
# [OK] 2024_11.csv → year_month=2024-11, rows=49841
# [OK] 2024_12.csv → year_month=2024-12, rows=43621
# [OK] 2025_01.csv → year_month=2025-01, rows=42819
# [OK] 2025_02.csv → year_month=2025-02, rows=37310
# [OK] 2025_03.csv → year_month=2025-03, rows=46930
# [OK] 2025_04.csv → year_month=2025-04, rows=61543
# [OK] 2025_05.csv → year_month=2025-05, rows=62404
# [OK] 2025_06.csv → year_month=2025-06, rows=59625
# [OK] 2025_07.csv → year_month=2025-07, rows=63320
#
# ✅ Merged 84 files → /mnt/cephfs-mount/chenchen/water_body_fraction_with_landcover&slope/2018to2025_water_fraction.csv
# Total rows: 4,468,597 | Columns: 31
# First 6 columns: ['year_month', 'datetime', 'date', 'julian_day', 'julian_date', 'sample']
